# %% [markdown]
# # Visualizing PMTiles
#
# [PMTiles](https://github.com/protomaps/PMTiles) is a single-file archive format for tiled data. A PMTiles archive can be hosted on a common storage platform such as S3, and enables low-cost, zero-maintenance map applications that are "serverless" - free of a custom tile backend or third party provider.

# %% [markdown]
# ## Installation
#
# Uncomment and run the following cell to install the dependencies.

# %%
# %pip install -U "leafmap[pmtiles]"
# Out:
# Requirement already satisfied: leafmap[pmtiles] in c:\anaconda\envs\gee\lib\site-packages (0.30.0)
# Requirement already satisfied: bqplot in c:\anaconda\envs\gee\lib\site-packages (from leafmap[pmtiles]) (0.12.42)
# Requirement already satisfied: colour in c:\anaconda\envs\gee\lib\site-packages (from leafmap[pmtiles]) (0.1.5)
# Requirement already satisfied: duckdb in c:\anaconda\envs\gee\lib\site-packages (from leafmap[pmtiles]) (0.9.2)
# Requirement already satisfied: folium in c:\anaconda\envs\gee\lib\site-packages (from leafmap[pmtiles]) (0.14.0)
# Requirement already satisfied: gdown in c:\anaconda\envs\gee\lib\site-packages (from leafmap[pmtiles]) (4.7.1)
# Requirement already satisfied: geojson in c:\anaconda\envs\gee\lib\site-packages (from leafmap[pmtiles]) (3.1.0)
# Requirement already satisfied: ipyevents in c:\anaconda\envs\gee\lib\site-packages (from leafmap[pmtiles]) (2.0.2)
# Requirement already satisfied: ipyfilechooser in c:\anaconda\envs\gee\lib\site-packages (from leafmap[pmtiles]) (0.6.0)
# Requirement already satisfied: ipyleaflet in c:\anaconda\envs\gee\lib\site-packages (from leafmap[pmtiles]) (0.18.0)
# Requirement already satisfied: ipywidgets in c:\anaconda\envs\gee\lib\site-packages (from leafmap[pmtiles]) (8.1.1)
# Requirement already satisfied: matplotlib in c:\anaconda\envs\gee\lib\site-packages (from leafmap[pmtiles]) (3.8.2)
# Requirement already satisfied: numpy in c:\anaconda\envs\gee\lib\site-packages (from leafmap[pmtiles]) (1.26.2)
# Requirement already satisfied: pandas in c:\anaconda\envs\gee\lib\site-packages (from leafmap[pmtiles]) (2.1.4)
# Requirement already satisfied: plotly in c:\anaconda\envs\gee\lib\site-packages (from leafmap[pmtiles]) (5.18.0)
# Requirement already satisfied: pyshp in c:\anaconda\envs\gee\lib\site-packages (from leafmap[pmtiles]) (2.3.1)
# Requirement already satisfied: pystac-client in c:\anaconda\envs\gee\lib\site-packages (from leafmap[pmtiles]) (0.7.5)
# Requirement already satisfied: python-box in c:\anaconda\envs\gee\lib\site-packages (from leafmap[pmtiles]) (7.1.1)
# Requirement already satisfied: scooby in c:\anaconda\envs\gee\lib\site-packages (from leafmap[pmtiles]) (0.9.2)
# Requirement already satisfied: whiteboxgui in c:\anaconda\envs\gee\lib\site-packages (from leafmap[pmtiles]) (2.3.0)
# Requirement already satisfied: xyzservices in c:\anaconda\envs\gee\lib\site-packages (from leafmap[pmtiles]) (2023.10.1)
# Requirement already satisfied: pmtiles in c:\anaconda\envs\gee\lib\site-packages (from leafmap[pmtiles]) (3.2.0)
# Requirement already satisfied: flask in c:\anaconda\envs\gee\lib\site-packages (from leafmap[pmtiles]) (2.3.3)
# Requirement already satisfied: flask-cors in c:\anaconda\envs\gee\lib\site-packages (from leafmap[pmtiles]) (4.0.0)
# Requirement already satisfied: traitlets>=4.3.0 in c:\anaconda\envs\gee\lib\site-packages (from bqplot->leafmap[pmtiles]) (5.14.0)
# Requirement already satisfied: traittypes>=0.0.6 in c:\anaconda\envs\gee\lib\site-packages (from bqplot->leafmap[pmtiles]) (0.2.1)
# Requirement already satisfied: comm>=0.1.3 in c:\anaconda\envs\gee\lib\site-packages (from ipywidgets->leafmap[pmtiles]) (0.1.4)
# Requirement already satisfied: ipython>=6.1.0 in c:\anaconda\envs\gee\lib\site-packages (from ipywidgets->leafmap[pmtiles]) (8.18.1)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in c:\anaconda\envs\gee\lib\site-packages (from ipywidgets->leafmap[pmtiles]) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in c:\anaconda\envs\gee\lib\site-packages (from ipywidgets->leafmap[pmtiles]) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\anaconda\envs\gee\lib\site-packages (from pandas->leafmap[pmtiles]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda\envs\gee\lib\site-packages (from pandas->leafmap[pmtiles]) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\anaconda\envs\gee\lib\site-packages (from pandas->leafmap[pmtiles]) (2023.3)
# Requirement already satisfied: Werkzeug>=2.3.7 in c:\anaconda\envs\gee\lib\site-packages (from flask->leafmap[pmtiles]) (3.0.1)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\gulab patel\appdata\roaming\python\python310\site-packages (from flask->leafmap[pmtiles]) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\anaconda\envs\gee\lib\site-packages (from flask->leafmap[pmtiles]) (2.1.2)
# Requirement already satisfied: click>=8.1.3 in c:\anaconda\envs\gee\lib\site-packages (from flask->leafmap[pmtiles]) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\anaconda\envs\gee\lib\site-packages (from flask->leafmap[pmtiles]) (1.7.0)
# Requirement already satisfied: branca>=0.6.0 in c:\anaconda\envs\gee\lib\site-packages (from folium->leafmap[pmtiles]) (0.7.0)
# Requirement already satisfied: requests in c:\anaconda\envs\gee\lib\site-packages (from folium->leafmap[pmtiles]) (2.31.0)
# Requirement already satisfied: filelock in c:\anaconda\envs\gee\lib\site-packages (from gdown->leafmap[pmtiles]) (3.13.1)
# Requirement already satisfied: six in c:\anaconda\envs\gee\lib\site-packages (from gdown->leafmap[pmtiles]) (1.16.0)
# Requirement already satisfied: tqdm in c:\anaconda\envs\gee\lib\site-packages (from gdown->leafmap[pmtiles]) (4.66.1)
# Requirement already satisfied: beautifulsoup4 in c:\anaconda\envs\gee\lib\site-packages (from gdown->leafmap[pmtiles]) (4.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\anaconda\envs\gee\lib\site-packages (from matplotlib->leafmap[pmtiles]) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\anaconda\envs\gee\lib\site-packages (from matplotlib->leafmap[pmtiles]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\anaconda\envs\gee\lib\site-packages (from matplotlib->leafmap[pmtiles]) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\anaconda\envs\gee\lib\site-packages (from matplotlib->leafmap[pmtiles]) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\anaconda\envs\gee\lib\site-packages (from matplotlib->leafmap[pmtiles]) (23.2)
# Requirement already satisfied: pillow>=8 in c:\anaconda\envs\gee\lib\site-packages (from matplotlib->leafmap[pmtiles]) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\anaconda\envs\gee\lib\site-packages (from matplotlib->leafmap[pmtiles]) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\anaconda\envs\gee\lib\site-packages (from plotly->leafmap[pmtiles]) (8.2.3)
# Requirement already satisfied: pystac>=1.8.2 in c:\anaconda\envs\gee\lib\site-packages (from pystac[validation]>=1.8.2->pystac-client->leafmap[pmtiles]) (1.9.0)
# Requirement already satisfied: ipytree in c:\anaconda\envs\gee\lib\site-packages (from whiteboxgui->leafmap[pmtiles]) (0.2.2)
# Requirement already satisfied: whitebox in c:\anaconda\envs\gee\lib\site-packages (from whiteboxgui->leafmap[pmtiles]) (2.3.1)
# Requirement already satisfied: colorama in c:\anaconda\envs\gee\lib\site-packages (from click>=8.1.3->flask->leafmap[pmtiles]) (0.4.6)
# Requirement already satisfied: decorator in c:\anaconda\envs\gee\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap[pmtiles]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\anaconda\envs\gee\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap[pmtiles]) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\anaconda\envs\gee\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap[pmtiles]) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\anaconda\envs\gee\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap[pmtiles]) (3.0.41)
# Requirement already satisfied: pygments>=2.4.0 in c:\anaconda\envs\gee\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap[pmtiles]) (2.17.2)
# Requirement already satisfied: stack-data in c:\anaconda\envs\gee\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap[pmtiles]) (0.6.2)
# Requirement already satisfied: exceptiongroup in c:\anaconda\envs\gee\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap[pmtiles]) (1.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\gulab patel\appdata\roaming\python\python310\site-packages (from Jinja2>=3.1.2->flask->leafmap[pmtiles]) (2.1.3)
# Requirement already satisfied: jsonschema~=4.18 in c:\anaconda\envs\gee\lib\site-packages (from pystac[validation]>=1.8.2->pystac-client->leafmap[pmtiles]) (4.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\anaconda\envs\gee\lib\site-packages (from requests->folium->leafmap[pmtiles]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda\envs\gee\lib\site-packages (from requests->folium->leafmap[pmtiles]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda\envs\gee\lib\site-packages (from requests->folium->leafmap[pmtiles]) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda\envs\gee\lib\site-packages (from requests->folium->leafmap[pmtiles]) (2023.11.17)
# Requirement already satisfied: soupsieve>1.2 in c:\anaconda\envs\gee\lib\site-packages (from beautifulsoup4->gdown->leafmap[pmtiles]) (2.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\anaconda\envs\gee\lib\site-packages (from requests[socks]->gdown->leafmap[pmtiles]) (1.7.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\anaconda\envs\gee\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->leafmap[pmtiles]) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\anaconda\envs\gee\lib\site-packages (from jsonschema~=4.18->pystac[validation]>=1.8.2->pystac-client->leafmap[pmtiles]) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\anaconda\envs\gee\lib\site-packages (from jsonschema~=4.18->pystac[validation]>=1.8.2->pystac-client->leafmap[pmtiles]) (2023.11.2)
# Requirement already satisfied: referencing>=0.28.4 in c:\anaconda\envs\gee\lib\site-packages (from jsonschema~=4.18->pystac[validation]>=1.8.2->pystac-client->leafmap[pmtiles]) (0.31.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\anaconda\envs\gee\lib\site-packages (from jsonschema~=4.18->pystac[validation]>=1.8.2->pystac-client->leafmap[pmtiles]) (0.13.2)
# Requirement already satisfied: wcwidth in c:\anaconda\envs\gee\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->leafmap[pmtiles]) (0.2.12)
# Requirement already satisfied: executing>=1.2.0 in c:\anaconda\envs\gee\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->leafmap[pmtiles]) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\anaconda\envs\gee\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->leafmap[pmtiles]) (2.4.1)
# Requirement already satisfied: pure-eval in c:\anaconda\envs\gee\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->leafmap[pmtiles]) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import libraries
#
# Currently, ipyleaflet does not support PMTiles. We will use folium mapping backend with leafmap.

# %%
import leafmap.foliumap as leafmap

# %% [markdown]
# ## PMTiles Viewer
#
# The [PMTiles Viewer](https://protomaps.github.io/PMTiles) can be used to view the contents of a PMTiles archive using a web browser. This is a useful tool for visualizing the contents of a PMTiles archive without writing any code. However, you can't use it with Jupyter notebook.

# %% [markdown]
# ## Remote PMTiles
#
# PMTiles can be hosted on a cloud storage platform or locally. In this section, we will visualize a PMTiles hosted on a remote server.
#
# ### Protomaps sample data
#
# The [PMTiles Viewer](https://protomaps.github.io/PMTiles) provides a list of sample PMTiles archives. We will use the [ODbL_firenze.pmtiles](https://protomaps.github.io/PMTiles/protomaps(vector)ODbL_firenze.pmtiles). First, let's inspect the metadata of the PMTiles archive.

# %%
url = "https://protomaps.github.io/PMTiles/protomaps(vector)ODbL_firenze.pmtiles"
metadata = leafmap.pmtiles_metadata(url)
metadata
# Out:
# {'attribution': '<a href="https://protomaps.com" target="_blank">Protomaps</a> © <a href="https://www.openstreetmap.org" target="_blank"> OpenStreetMap</a>',
#  'name': 'protomaps 2023-01-18T07:49:39Z',
#  'type': 'baselayer',
#  'vector_layers': [{'fields': {}, 'id': 'earth'},
#   {'fields': {'boundary': 'string',
#     'landuse': 'string',
#     'leisure': 'string',
#     'name': 'string',
#     'natural': 'string'},
#    'id': 'natural'},
#   {'fields': {'aeroway': 'string',
#     'amenity': 'string',
#     'area:aeroway': 'string',
#     'highway': 'string',
#     'landuse': 'string',
#     'leisure': 'string',
#     'man_made': 'string',
#     'name': 'string',
#     'place': 'string',
#     'pmap:kind': 'string',
#     'railway': 'string',
#     'sport': 'string'},
#    'id': 'land'},
#   {'fields': {'landuse': 'string',
#     'leisure': 'string',
#     'name': 'string',
#     'natural': 'string',
#     'water': 'string',
#     'waterway': 'string'},
#    'id': 'water'},
#   {'fields': {'natural': 'string', 'waterway': 'string'},
#    'id': 'physical_line'},
#   {'fields': {'building:part': 'string',
#     'height': 'number',
#     'layer': 'string',
#     'name': 'string'},
#    'id': 'buildings'},
#   {'fields': {'ele': 'number',
#     'name': 'string',
#     'natural': 'string',
#     'place': 'string'},
#    'id': 'physical_point'},
#   {'fields': {'capital': 'string',
#     'country_code_iso3166_1_alpha_2': 'string',
#     'name': 'string',
#     'place': 'string',
#     'pmap:kind': 'string',
#     'pmap:rank': 'string',
#     'population': 'string'},
#    'id': 'places'},
#   {'fields': {'bridge': 'string',
#     'highway': 'string',
#     'layer': 'string',
#     'oneway': 'string',
#     'pmap:kind': 'string',
#     'ref': 'string',
#     'tunnel': 'string'},
#    'id': 'roads'},
#   {'fields': {'aerialway': 'string',
#     'aeroway': 'string',
#     'highspeed': 'string',
#     'layer': 'string',
#     'name': 'string',
#     'network': 'string',
#     'pmap:kind': 'string',
#     'railway': 'string',
#     'ref': 'string',
#     'route': 'string',
#     'service': 'string'},
#    'id': 'transit'},
#   {'fields': {'amenity': 'string',
#     'cuisine': 'string',
#     'name': 'string',
#     'railway': 'string',
#     'religion': 'string',
#     'shop': 'string',
#     'tourism': 'string'},
#    'id': 'pois'},
#   {'fields': {'pmap:min_admin_level': 'number'}, 'id': 'boundaries'},
#   {'fields': {}, 'id': 'mask'}],
#  'layer_names': ['earth',
#   'natural',
#   'land',
#   'water',
#   'physical_line',
#   'buildings',
#   'physical_point',
#   'places',
#   'roads',
#   'transit',
#   'pois',
#   'boundaries',
#   'mask'],
#  'center': [43.779779, 11.2414827],
#  'bounds': [11.154026, 43.7270125, 11.3289395, 43.8325455]}

# %% [markdown]
# Get the list of layers.

# %%
print(f"layer names: {metadata['layer_names']}")
# Out:
# layer names: ['earth', 'natural', 'land', 'water', 'physical_line', 'buildings', 'physical_point', 'places', 'roads', 'transit', 'pois', 'boundaries', 'mask']

# %% [markdown]
# Get the layer center.

# %%
print(f"center: {metadata['center']}")
# Out:
# center: [43.779779, 11.2414827]

# %% [markdown]
# Get the layer bounds.

# %%
print(f"bounds: {metadata['bounds']}")
# Out:
# bounds: [11.154026, 43.7270125, 11.3289395, 43.8325455]

# %% [markdown]
# Visualize the layer with the default style.

# %%
style = leafmap.pmtiles_style(url, cmap='Set3')
style
# Out:
# {'version': 8,
#  'sources': {'source': {'type': 'vector',
#    'url': 'pmtiles://https://protomaps.github.io/PMTiles/protomaps(vector)ODbL_firenze.pmtiles',
#    'attribution': 'PMTiles'}},
#  'layers': [{'id': 'earth_point',
#    'source': 'source',
#    'source-layer': 'earth',
#    'type': 'circle',
#    'paint': {'circle-color': '#8dd3c7', 'circle-radius': 5},
#    'filter': ['==', ['geometry-type'], 'Point']},
#   {'id': 'earth_stroke',
#    'source': 'source',
#    'source-layer': 'earth',
#    'type': 'line',
#    'paint': {'line-color': '#8dd3c7', 'line-width': 1},
#    'filter': ['==', ['geometry-type'], 'LineString']},
#   {'id': 'earth_fill',
#    'source': 'source',
#    'source-layer': 'earth',
#    'type': 'fill',
#    'paint': {'fill-color': '#8dd3c7', 'fill-opacity': 0.5},
#    'filter': ['==', ['geometry-type'], 'Polygon']},
#   {'id': 'natural_point',
#    'source': 'source',
#    'source-layer': 'natural',
#    'type': 'circle',
#    'paint': {'circle-color': '#ffffb3', 'circle-radius': 5},
#    'filter': ['==', ['geometry-type'], 'Point']},
#   {'id': 'natural_stroke',
#    'source': 'source',
#    'source-layer': 'natural',
#    'type': 'line',
#    'paint': {'line-color': '#ffffb3', 'line-width': 1},
#    'filter': ['==', ['geometry-type'], 'LineString']},
#   {'id': 'natural_fill',
#    'source': 'source',
#    'source-layer': 'natural',
#    'type': 'fill',
#    'paint': {'fill-color': '#ffffb3', 'fill-opacity': 0.5},
#    'filter': ['==', ['geometry-type'], 'Polygon']},
#   {'id': 'land_point',
#    'source': 'source',
#    'source-layer': 'land',
#    'type': 'circle',
#    'paint': {'circle-color': '#bebada', 'circle-radius': 5},
#    'filter': ['==', ['geometry-type'], 'Point']},
#   {'id': 'land_stroke',
#    'source': 'source',
#    'source-layer': 'land',
#    'type': 'line',
#    'paint': {'line-color': '#bebada', 'line-width': 1},
#    'filter': ['==', ['geometry-type'], 'LineString']},
#   {'id': 'land_fill',
#    'source': 'source',
#    'source-layer': 'land',
#    'type': 'fill',
#    'paint': {'fill-color': '#bebada', 'fill-opacity': 0.5},
#    'filter': ['==', ['geometry-type'], 'Polygon']},
#   {'id': 'water_point',
#    'source': 'source',
#    'source-layer': 'water',
#    'type': 'circle',
#    'paint': {'circle-color': '#fb8072', 'circle-radius': 5},
#    'filter': ['==', ['geometry-type'], 'Point']},
#   {'id': 'water_stroke',
#    'source': 'source',
#    'source-layer': 'water',
#    'type': 'line',
#    'paint': {'line-color': '#fb8072', 'line-width': 1},
#    'filter': ['==', ['geometry-type'], 'LineString']},
#   {'id': 'water_fill',
#    'source': 'source',
#    'source-layer': 'water',
#    'type': 'fill',
#    'paint': {'fill-color': '#fb8072', 'fill-opacity': 0.5},
#    'filter': ['==', ['geometry-type'], 'Polygon']},
#   {'id': 'physical_line_point',
#    'source': 'source',
#    'source-layer': 'physical_line',
#    'type': 'circle',
#    'paint': {'circle-color': '#80b1d3', 'circle-radius': 5},
#    'filter': ['==', ['geometry-type'], 'Point']},
#   {'id': 'physical_line_stroke',
#    'source': 'source',
#    'source-layer': 'physical_line',
#    'type': 'line',
#    'paint': {'line-color': '#80b1d3', 'line-width': 1},
#    'filter': ['==', ['geometry-type'], 'LineString']},
#   {'id': 'physical_line_fill',
#    'source': 'source',
#    'source-layer': 'physical_line',
#    'type': 'fill',
#    'paint': {'fill-color': '#80b1d3', 'fill-opacity': 0.5},
#    'filter': ['==', ['geometry-type'], 'Polygon']},
#   {'id': 'buildings_point',
#    'source': 'source',
#    'source-layer': 'buildings',
#    'type': 'circle',
#    'paint': {'circle-color': '#fdb462', 'circle-radius': 5},
#    'filter': ['==', ['geometry-type'], 'Point']},
#   {'id': 'buildings_stroke',
#    'source': 'source',
#    'source-layer': 'buildings',
#    'type': 'line',
#    'paint': {'line-color': '#fdb462', 'line-width': 1},
#    'filter': ['==', ['geometry-type'], 'LineString']},
#   {'id': 'buildings_fill',
#    'source': 'source',
#    'source-layer': 'buildings',
#    'type': 'fill',
#    'paint': {'fill-color': '#fdb462', 'fill-opacity': 0.5},
#    'filter': ['==', ['geometry-type'], 'Polygon']},
#   {'id': 'physical_point_point',
#    'source': 'source',
#    'source-layer': 'physical_point',
#    'type': 'circle',
#    'paint': {'circle-color': '#b3de69', 'circle-radius': 5},
#    'filter': ['==', ['geometry-type'], 'Point']},
#   {'id': 'physical_point_stroke',
#    'source': 'source',
#    'source-layer': 'physical_point',
#    'type': 'line',
#    'paint': {'line-color': '#b3de69', 'line-width': 1},
#    'filter': ['==', ['geometry-type'], 'LineString']},
#   {'id': 'physical_point_fill',
#    'source': 'source',
#    'source-layer': 'physical_point',
#    'type': 'fill',
#    'paint': {'fill-color': '#b3de69', 'fill-opacity': 0.5},
#    'filter': ['==', ['geometry-type'], 'Polygon']},
#   {'id': 'places_point',
#    'source': 'source',
#    'source-layer': 'places',
#    'type': 'circle',
#    'paint': {'circle-color': '#fccde5', 'circle-radius': 5},
#    'filter': ['==', ['geometry-type'], 'Point']},
#   {'id': 'places_stroke',
#    'source': 'source',
#    'source-layer': 'places',
#    'type': 'line',
#    'paint': {'line-color': '#fccde5', 'line-width': 1},
#    'filter': ['==', ['geometry-type'], 'LineString']},
#   {'id': 'places_fill',
#    'source': 'source',
#    'source-layer': 'places',
#    'type': 'fill',
#    'paint': {'fill-color': '#fccde5', 'fill-opacity': 0.5},
#    'filter': ['==', ['geometry-type'], 'Polygon']},
#   {'id': 'roads_point',
#    'source': 'source',
#    'source-layer': 'roads',
#    'type': 'circle',
#    'paint': {'circle-color': '#d9d9d9', 'circle-radius': 5},
#    'filter': ['==', ['geometry-type'], 'Point']},
#   {'id': 'roads_stroke',
#    'source': 'source',
#    'source-layer': 'roads',
#    'type': 'line',
#    'paint': {'line-color': '#d9d9d9', 'line-width': 1},
#    'filter': ['==', ['geometry-type'], 'LineString']},
#   {'id': 'roads_fill',
#    'source': 'source',
#    'source-layer': 'roads',
#    'type': 'fill',
#    'paint': {'fill-color': '#d9d9d9', 'fill-opacity': 0.5},
#    'filter': ['==', ['geometry-type'], 'Polygon']},
#   {'id': 'transit_point',
#    'source': 'source',
#    'source-layer': 'transit',
#    'type': 'circle',
#    'paint': {'circle-color': '#bc80bd', 'circle-radius': 5},
#    'filter': ['==', ['geometry-type'], 'Point']},
#   {'id': 'transit_stroke',
#    'source': 'source',
#    'source-layer': 'transit',
#    'type': 'line',
#    'paint': {'line-color': '#bc80bd', 'line-width': 1},
#    'filter': ['==', ['geometry-type'], 'LineString']},
#   {'id': 'transit_fill',
#    'source': 'source',
#    'source-layer': 'transit',
#    'type': 'fill',
#    'paint': {'fill-color': '#bc80bd', 'fill-opacity': 0.5},
#    'filter': ['==', ['geometry-type'], 'Polygon']},
#   {'id': 'pois_point',
#    'source': 'source',
#    'source-layer': 'pois',
#    'type': 'circle',
#    'paint': {'circle-color': '#ccebc5', 'circle-radius': 5},
#    'filter': ['==', ['geometry-type'], 'Point']},
#   {'id': 'pois_stroke',
#    'source': 'source',
#    'source-layer': 'pois',
#    'type': 'line',
#    'paint': {'line-color': '#ccebc5', 'line-width': 1},
#    'filter': ['==', ['geometry-type'], 'LineString']},
#   {'id': 'pois_fill',
#    'source': 'source',
#    'source-layer': 'pois',
#    'type': 'fill',
#    'paint': {'fill-color': '#ccebc5', 'fill-opacity': 0.5},
#    'filter': ['==', ['geometry-type'], 'Polygon']},
#   {'id': 'boundaries_point',
#    'source': 'source',
#    'source-layer': 'boundaries',
#    'type': 'circle',
#    'paint': {'circle-color': '#ffed6f', 'circle-radius': 5},
#    'filter': ['==', ['geometry-type'], 'Point']},
#   {'id': 'boundaries_stroke',
#    'source': 'source',
#    'source-layer': 'boundaries',
#    'type': 'line',
#    'paint': {'line-color': '#ffed6f', 'line-width': 1},
#    'filter': ['==', ['geometry-type'], 'LineString']},
#   {'id': 'boundaries_fill',
#    'source': 'source',
#    'source-layer': 'boundaries',
#    'type': 'fill',
#    'paint': {'fill-color': '#ffed6f', 'fill-opacity': 0.5},
#    'filter': ['==', ['geometry-type'], 'Polygon']},
#   {'id': 'mask_point',
#    'source': 'source',
#    'source-layer': 'mask',
#    'type': 'circle',
#    'paint': {'circle-color': '#8dd3c7', 'circle-radius': 5},
#    'filter': ['==', ['geometry-type'], 'Point']},
#   {'id': 'mask_stroke',
#    'source': 'source',
#    'source-layer': 'mask',
#    'type': 'line',
#    'paint': {'line-color': '#8dd3c7', 'line-width': 1},
#    'filter': ['==', ['geometry-type'], 'LineString']},
#   {'id': 'mask_fill',
#    'source': 'source',
#    'source-layer': 'mask',
#    'type': 'fill',
#    'paint': {'fill-color': '#8dd3c7', 'fill-opacity': 0.5},
#    'filter': ['==', ['geometry-type'], 'Polygon']}]}

# %%
m = leafmap.Map()
m.add_basemap('CartoDB.DarkMatter')
m.add_pmtiles(
    url, 
    name='PMTiles', 
    style=style, 
    zoom_to_layer=True,
    tooltip=False,
)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a937ee134474a9aa3428b0c6783300d9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/pmtiles@2.7.1/dist/index.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/maplibre-gl@2.2.1/dist/maplibre-gl.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/@maplibre/maplibre-gl-leaflet@0.0.19/leaflet-maplibre-gl.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/maplibre-gl@2.4.0/dist/maplibre-gl.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a937ee134474a9aa3428b0c6783300d9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a937ee134474a9aa3428b0c6783300d9 = L.map(
#                 &quot;map_a937ee134474a9aa3428b0c6783300d9&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     drawExport: false,
#                     layersControl: true,
#                 }
#             );
#             L.control.scale().addTo(map_a937ee134474a9aa3428b0c6783300d9);
#
#
#
#
#
#             var tile_layer_03921433ba77ab5ea71a6bf0fefdaf2f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a937ee134474a9aa3428b0c6783300d9);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_a937ee134474a9aa3428b0c6783300d9);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems = new L.featureGroup().addTo(
#                 map_a937ee134474a9aa3428b0c6783300d9
#             );
#             options.edit.featureGroup = drawnItems;
#             var draw_control_d713c088b490e5707e48d7139ccbac1a = new L.Control.Draw(
#                 options
#             ).addTo( map_a937ee134474a9aa3428b0c6783300d9 );
#             map_a937ee134474a9aa3428b0c6783300d9.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems.addLayer(layer);
#              });
#             map_a937ee134474a9aa3428b0c6783300d9.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems.addLayer(e.layer);
#             });
#
#
#
#             var measure_control_99bb10c1f1c49d32f21573906c6bd9a4 = new L.Control.Measure(
#                 {&quot;position&quot;: &quot;bottomleft&quot;, &quot;primaryAreaUnit&quot;: &quot;sqmeters&quot;, &quot;primaryLengthUnit&quot;: &quot;meters&quot;, &quot;secondaryAreaUnit&quot;: &quot;acres&quot;, &quot;secondaryLengthUnit&quot;: &quot;miles&quot;});
#             map_a937ee134474a9aa3428b0c6783300d9.addControl(measure_control_99bb10c1f1c49d32f21573906c6bd9a4);
#
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_a937ee134474a9aa3428b0c6783300d9.setView(e.geocode.center, 11);
#             }).addTo(map_a937ee134474a9aa3428b0c6783300d9);
#
#
#
#             map_a937ee134474a9aa3428b0c6783300d9.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#             var tile_layer_4296bf6aeef3c0e27d5512ba3573ebc9 = L.tileLayer(
#                 &quot;https://a

# %% [markdown]
# Visualize the layer with a custom style.

# %%
m = leafmap.Map()

style = {
    "version": 8,
    "sources": {
        "example_source": {
            "type": "vector",
            "url": "pmtiles://" + url,
            "attribution": 'PMTiles',
        }
    },
    "layers": [
        {
            "id": "buildings",
            "source": "example_source",
            "source-layer": "landuse",
            "type": "fill",
            "paint": {"fill-color": "steelblue"},
        },
        {
            "id": "roads",
            "source": "example_source",
            "source-layer": "roads",
            "type": "line",
            "paint": {"line-color": "black"},
        },
    ],
}

m.add_pmtiles(
    url, name='PMTiles', style=style, zoom_to_layer=True, tooltip=True
)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5eb77b0ee4dcb3d9a1a0b09677db7e03 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/pmtiles@2.7.1/dist/index.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/maplibre-gl@2.2.1/dist/maplibre-gl.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/@maplibre/maplibre-gl-leaflet@0.0.19/leaflet-maplibre-gl.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/maplibre-gl@2.4.0/dist/maplibre-gl.css&quot;/&gt;
#
#             &lt;style&gt;
#             .maplibregl-popup {
#                 font: 12px/20px &#x27;Helvetica Neue&#x27;, Arial, Helvetica, sans-serif;
#                 z-index: 651;
#             }
#             .feature-row{
#                 margin-bottom: 0.5em;
#                 &amp;:not(:last-of-type) {
#                     border-bottom: 1px solid black;
#                 }
#             }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5eb77b0ee4dcb3d9a1a0b09677db7e03&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5eb77b0ee4dcb3d9a1a0b09677db7e03 = L.map(
#                 &quot;map_5eb77b0ee4dcb3d9a1a0b09677db7e03&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     drawExport: false,
#                     layersControl: true,
#                 }
#             );
#             L.control.scale().addTo(map_5eb77b0ee4dcb3d9a1a0b09677db7e03);
#
#
#
#
#
#             var tile_layer_88f2b57871e84a75921a2894acb62892 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5eb77b0ee4dcb3d9a1a0b09677db7e03);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_5eb77b0ee4dcb3d9a1a0b09677db7e03);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems = new L.featureGroup().addTo(
#                 map_5eb77b0ee4dcb3d9a1a0b09677db7e03
#             );
#             options.edit.featureGroup = drawnItems;
#             var draw_control_777244fb14c12bc73e2a6c838777d2a3 = new L.Control.Draw(
#                 options
#             ).addTo( map_5eb77b0ee4dcb3d9a1a0b09677db7e03 );
#             map_5eb77b0ee4dcb3d9a1a0b09677db7e03.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems.addLayer(layer);
#              });
#             map_5eb77b0ee4dcb3d9a1a0b09677db7e03.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems.addLayer(e.layer);
#             });
#
#
#
#             var measure_control_995985bae6a4effa1028fd853fb528a9 = new L.Control.Measure(
#                 {&quot;position&quot;: &quot;bottomleft&quot;, &quot;primaryAreaUnit&quot;: &quot;sqmeters&quot;, &quot;primaryLengthUnit&quot;: &quot;meters&quot;, &quot;secondaryAreaUnit&quot;: &quot;acres&quot;, &quot;secondaryLengthUnit&quot;: &quot;miles&quot;});
#             map_5eb77b0ee4dcb3d9a1a0b09677db7e03.addControl(measure_control_995985bae6a4effa1028fd853fb528a9);
#
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {

# %% [markdown]
# ### Overture data

# %% [markdown]
# You can also visualize [Overture data](https://overturemaps.org/). First, let's inspect the metadata of the PMTiles archive.

# %%
url = "https://storage.googleapis.com/ahp-research/overture/pmtiles/overture.pmtiles"
metadata = leafmap.pmtiles_metadata(url)
print(f"layer names: {metadata['layer_names']}")
print(f"bounds: {metadata['bounds']}")
# Out:
# layer names: ['admins', 'buildings', 'places', 'roads']
# bounds: [3.295898, 50.746884, 7.245483, 53.5762]

# %% [markdown]
# Visualize the layer with the default style.

# %%
m = leafmap.Map(height='800px')
m.add_basemap('CartoDB.DarkMatter')
m.add_pmtiles(url, name='PMTiles', tooltip=False)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_31c930a357afbea7add0d2e0e5383549 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/pmtiles@2.7.1/dist/index.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/maplibre-gl@2.2.1/dist/maplibre-gl.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/@maplibre/maplibre-gl-leaflet@0.0.19/leaflet-maplibre-gl.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/maplibre-gl@2.4.0/dist/maplibre-gl.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_31c930a357afbea7add0d2e0e5383549&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_31c930a357afbea7add0d2e0e5383549 = L.map(
#                 &quot;map_31c930a357afbea7add0d2e0e5383549&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     drawExport: false,
#                     layersControl: true,
#                 }
#             );
#             L.control.scale().addTo(map_31c930a357afbea7add0d2e0e5383549);
#
#
#
#
#
#             var tile_layer_429a6c6a341dfa51553b3c53d868694b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_31c930a357afbea7add0d2e0e5383549);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_31c930a357afbea7add0d2e0e5383549);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems = new L.featureGroup().addTo(
#                 map_31c930a357afbea7add0d2e0e5383549
#             );
#             options.edit.featureGroup = drawnItems;
#             var draw_control_e4bf01262524c9160ce5deab0bd64b24 = new L.Control.Draw(
#                 options
#             ).addTo( map_31c930a357afbea7add0d2e0e5383549 );
#             map_31c930a357afbea7add0d2e0e5383549.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems.addLayer(layer);
#              });
#             map_31c930a357afbea7add0d2e0e5383549.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems.addLayer(e.layer);
#             });
#
#
#
#             var measure_control_7709ad16f6d32cfebbba0d9ef01622cd = new L.Control.Measure(
#                 {&quot;position&quot;: &quot;bottomleft&quot;, &quot;primaryAreaUnit&quot;: &quot;sqmeters&quot;, &quot;primaryLengthUnit&quot;: &quot;meters&quot;, &quot;secondaryAreaUnit&quot;: &quot;acres&quot;, &quot;secondaryLengthUnit&quot;: &quot;miles&quot;});
#             map_31c930a357afbea7add0d2e0e5383549.addControl(measure_control_7709ad16f6d32cfebbba0d9ef01622cd);
#
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_31c930a357afbea7add0d2e0e5383549.setView(e.geocode.center, 11);
#             }).addTo(map_31c930a357afbea7add0d2e0e5383549);
#
#
#
#             map_31c930a357afbea7add0d2e0e5383549.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#             var tile_layer_4296bf6aeef3c0e27d5512ba3573ebc9 = L.tileLayer(
#                 &quot;https://a

# %% [markdown]
# Visualize the layer with a custom style.

# %%
m = leafmap.Map(height='800px')
m.add_basemap('CartoDB.DarkMatter')

style = {
    "version": 8,
    "sources": {
        "example_source": {
            "type": "vector",
            "url": "pmtiles://" + url,
            "attribution": 'PMTiles',
        }
    },
    "layers": [
        {
            "id": "admins",
            "source": "example_source",
            "source-layer": "admins",
            "type": "fill",
            "paint": {"fill-color": "#BDD3C7", "fill-opacity": 0.1},
        },
        {
            "id": "buildings",
            "source": "example_source",
            "source-layer": "buildings",
            "type": "fill",
            "paint": {"fill-color": "#FFFFB3", "fill-opacity": 0.5},
        },
        {
            "id": "places",
            "source": "example_source",
            "source-layer": "places",
            "type": "fill",
            "paint": {"fill-color": "#BEBADA", "fill-opacity": 0.5},
        },
        {
            "id": "roads",
            "source": "example_source",
            "source-layer": "roads",
            "type": "line",
            "paint": {"line-color": "#FB8072"},
        },
    ],
}

m.add_pmtiles(url, name='PMTiles', style=style, tooltip=False)

legend_dict = {
    'admins': 'BDD3C7',
    'buildings': 'FFFFB3',
    'places': 'BEBADA',
    'roads': 'FB8072',
}

m.add_legend(legend_dict=legend_dict)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_98787e67bc1c6b20f45b5b0b66565439 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/pmtiles@2.7.1/dist/index.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/maplibre-gl@2.2.1/dist/maplibre-gl.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/@maplibre/maplibre-gl-leaflet@0.0.19/leaflet-maplibre-gl.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/maplibre-gl@2.4.0/dist/maplibre-gl.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_98787e67bc1c6b20f45b5b0b66565439&quot; &gt;&lt;/div&gt;
#
#
# &lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#   &lt;meta charset=&quot;utf-8&quot;&gt;
#   &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1&quot;&gt;
#   &lt;title&gt;jQuery UI Draggable - Default functionality&lt;/title&gt;
#   &lt;link rel=&quot;stylesheet&quot; href=&quot;//code.jquery.com/ui/1.12.1/themes/base/jquery-ui.css&quot;&gt;
#
#   &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.js&quot;&gt;&lt;/script&gt;
#   &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#
#   &lt;script&gt;
#   $( function() {
#     $( &quot;#maplegend&quot; ).draggable({
#                     start: function (event, ui) {
#                         $(this).css({
#                             right: &quot;auto&quot;,
#                             top: &quot;auto&quot;,
#                             bottom: &quot;auto&quot;
#                         });
#                     }
#                 });
# });
#
#   &lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div id=&#x27;maplegend&#x27; class=&#x27;maplegend&#x27;
#     style=&#x27;position: absolute; z-index:9999; border:2px solid grey; background-color:rgba(255, 255, 255, 0.8);
#      border-radius:6px; padding: 10px; font-size:14px; right: 20px; bottom: 20px;&#x27;&gt;
#
# &lt;div class=&#x27;legend-title&#x27;&gt;Legend&lt;/div&gt;
# &lt;div class=&#x27;legend-scale&#x27;&gt;
#   &lt;ul class=&#x27;legend-labels&#x27;&gt;
#     &lt;li&gt;&lt;span style=&#x27;background:#bdd3c7;opacity:1.0;&#x27;&gt;&lt;/span&gt;admins&lt;/li&gt;
#     &lt;li&gt;&lt;span style=&#x27;background:#ffffb3;opacity:1.0;&#x27;&gt;&lt;/span&gt;buildings&lt;/li&gt;
#     &lt;li&gt;&lt;span style=&#x27;background:#bebada;opacity:1.0;&#x27;&gt;&lt;/span&gt;places&lt;/li&gt;
#     &lt;li&gt;&lt;span style=&#x27;background:#fb8072;opacity:1.0;&#x27;&gt;&lt;/span&gt;roads&lt;/li&gt;
#   &lt;/ul&gt;
# &lt;/div&gt;
# &lt;/div&gt;
#
# &lt;/body&gt;
# &lt;/html&gt;
#
# &lt;style type=&#x27;text/css&#x27;&gt;
#   .maplegend .legend-title {
#     text-align: left;
#     margin-bottom: 5px;
#     font-weight: bold;
#     font-size: 90%;
#     }
#   .maplegend .legend-scale ul {
#     margin: 0;
#     margin-bottom: 5px;
#     padding: 0;
#     float: left;
#     list-style: none;
#     }
#   .maplegend .legend-scale ul li {
#     font-size: 80%;
#     list-style: none;
#     margin-left: 0;
#     line-height: 18px;
#     margin-bottom: 2px;
#     }
#   .maplegend ul.legend-labels li span {
#     display: block;
#     float: left;
#     height: 16px;
#     width: 30px;
#     margin-right: 5px;
#     margin-left: 0;
#     border: 1px solid #999;
#     }
#   .maplegend .legend-source {
#     font-size: 80%;
#     color: #777;
#     clear: both;
#     }
#   .maplegend a {
#     color: #777;
#     }
# &lt;/style&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_98787e67bc1c6b20f45b5b0b66565439 = L.map(
#                 &quot;map_98787e67bc1c6b20f45b5b0b66565439&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     drawExport: false,
#                     layersControl: true,
#                 }
#             );
#             L.control.scale().addTo(map_98787e67bc1c6b20f45b5b0b66565439);
#
#
#
#
#
#             var tile_layer_395eea55ed5bb86c4a937a1075fff11e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;su

# %% [markdown]
# ### Source Cooperative
#
# [Source Cooperative](https://source.coop) hosts a variety of open geospatial data in PMTiles format. In this example, we will visualize the [Google-Microsoft Open Buildings](https://beta.source.coop/repositories/vida/google-microsoft-open-buildings/description) dataset (193.9 GB). First, let's inspect the metadata of the PMTiles archive.

# %%
url = 'https://data.source.coop/vida/google-microsoft-open-buildings/pmtiles/go_ms_building_footprints.pmtiles'
metadata = leafmap.pmtiles_metadata(url)
print(f"layer names: {metadata['layer_names']}")
print(f"bounds: {metadata['bounds']}")
# Out:
# layer names: ['building_footprints']
# bounds: [-160.221701, -55.9756776, 166.709685, 74.7731168]

# %%
m = leafmap.Map(center=[20, 0], zoom=2, height='800px')
m.add_basemap('CartoDB.DarkMatter')
m.add_basemap('Esri.WorldImagery', show=False)

style = {
    "version": 8,
    "sources": {
        "example_source": {
            "type": "vector",
            "url": "pmtiles://" + url,
            "attribution": 'PMTiles',
        }
    },
    "layers": [
        {
            "id": "buildings",
            "source": "example_source",
            "source-layer": "building_footprints",
            "type": "fill",
            "paint": {"fill-color": "#3388ff", "fill-opacity": 0.5},
        },
    ],
}

m.add_pmtiles(
    url, name='Buildings', style=style, tooltip=False
)

html = "Source: <a href='https://beta.source.coop/repositories/vida/google-microsoft-open-buildings/description' target='_blank'>source.coop</a>"
m.add_html(html, position='bottomright')

m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e476dd4a632ca1b3c078a707021830ec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/pmtiles@2.7.1/dist/index.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/maplibre-gl@2.2.1/dist/maplibre-gl.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/@maplibre/maplibre-gl-leaflet@0.0.19/leaflet-maplibre-gl.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/maplibre-gl@2.4.0/dist/maplibre-gl.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e476dd4a632ca1b3c078a707021830ec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e476dd4a632ca1b3c078a707021830ec = L.map(
#                 &quot;map_e476dd4a632ca1b3c078a707021830ec&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     drawExport: false,
#                     layersControl: true,
#                 }
#             );
#             L.control.scale().addTo(map_e476dd4a632ca1b3c078a707021830ec);
#
#
#
#
#
#             var tile_layer_b50773b5b252bdc51006f16c8e10b015 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e476dd4a632ca1b3c078a707021830ec);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_e476dd4a632ca1b3c078a707021830ec);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems = new L.featureGroup().addTo(
#                 map_e476dd4a632ca1b3c078a707021830ec
#             );
#             options.edit.featureGroup = drawnItems;
#             var draw_control_41ebcfff74473d0871d7bcdbd571043f = new L.Control.Draw(
#                 options
#             ).addTo( map_e476dd4a632ca1b3c078a707021830ec );
#             map_e476dd4a632ca1b3c078a707021830ec.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems.addLayer(layer);
#              });
#             map_e476dd4a632ca1b3c078a707021830ec.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems.addLayer(e.layer);
#             });
#
#
#
#             var measure_control_714faec4adb22ac80985ed3bed14d9dc = new L.Control.Measure(
#                 {&quot;position&quot;: &quot;bottomleft&quot;, &quot;primaryAreaUnit&quot;: &quot;sqmeters&quot;, &quot;primaryLengthUnit&quot;: &quot;meters&quot;, &quot;secondaryAreaUnit&quot;: &quot;acres&quot;, &quot;secondaryLengthUnit&quot;: &quot;miles&quot;});
#             map_e476dd4a632ca1b3c078a707021830ec.addControl(measure_control_714faec4adb22ac80985ed3bed14d9dc);
#
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_e476dd4a632ca1b3c078a707021830ec.setView(e.geocode.center, 11);
#             }).addTo(map_e476dd4a632ca1b3c078a707021830ec);
#
#
#
#             map_e476dd4a632ca1b3c078a707021830ec.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#             var tile_layer_4296bf6aeef3c0e27d5512ba3573ebc9 = L.tileLayer(
#                 &quot;https://a

# %%
m.save('buildings.html')

# %% [markdown]
# ## Local PMTiles
#
# tippecanoe is required to convert vector data to pmtiles. Install it with `mamba install -c conda-forge tippecanoe`.
#
# Download [building footprints](https://github.com/opengeos/open-data/blob/main/datasets/libya/Derna_buildings.geojson) of Derna, Libya.

# %%
url = 'https://raw.githubusercontent.com/opengeos/open-data/main/datasets/libya/Derna_buildings.geojson'
leafmap.download_file(url, 'buildings.geojson')
# Out:
# Downloading...
# From: https://raw.githubusercontent.com/opengeos/open-data/main/datasets/libya/Derna_buildings.geojson
# To: d:\DataScience\AIAg\book\duckdb\buildings.geojson
#   0%|          | 0.00/2.77M [00:00<?, ?B/s][Errno 28] No space left on device
#   0%|          | 0.00/2.77M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10292\2802782677.py in ?()
#       1 url = 'https://raw.githubusercontent.com/opengeos/open-data/main/datasets/libya/Derna_buildings.geojson'
# ----> 2 leafmap.download_file(url, 'buildings.geojson')
#
# c:\anaconda\envs\gee\lib\site-packages\leafmap\common.py in ?(url, output, quiet, proxy, speed, use_cookies, verify, id, fuzzy, resume, unzip, overwrite, subfolder)
#    4458         url, output, quiet, proxy, speed, use_cookies, verify, id, fuzzy, resume
#    4459     )
#    4460
#    4461     if unzip:
# -> 4462         if output.endswith(".zip"):
#    4463             with zipfile.ZipFile(output, "r") as zip_ref:
#    4464                 if not quiet:
#    4465                     print("Extracting files...")
#
# AttributeError: 'NoneType' object has no attribute 'endswith'

# %% [markdown]
# Convert vector to PMTiles.

# %%
pmtiles = 'buildings.pmtiles'
leafmap.geojson_to_pmtiles(
    'buildings.geojson', 
    pmtiles, 
    layer_name='buildings', 
    overwrite=True, 
    quiet=True
)

# %% [markdown]
# Start a HTTP Sever

# %%
leafmap.start_server(port=8000)

# %%
url = f'http://127.0.0.1:8000/{pmtiles}'
# leafmap.pmtiles_metadata(url)

# %% [markdown]
# Diplay the PMTiles on the map.

# %%
m = leafmap.Map()
m.add_basemap('CartoDB.DarkMatter')
m.add_basemap('SATELLITE')

style = {
    "version": 8,
    "sources": {
        "example_source": {
            "type": "vector",
            "url": "pmtiles://" + url,
            "attribution": 'PMTiles',
        }
    },
    "layers": [
        {
            "id": "buildings",
            "source": "example_source",
            "source-layer": "buildings",
            "type": "fill",
            "paint": {"fill-color": "#3388ff", "fill-opacity": 0.5},
        },
    ],
}

# style = leafmap.pmtiles_style(url)  # Use default style

m.add_pmtiles(url, name='Buildings', show=True, zoom_to_layer=True, style=style)
m
