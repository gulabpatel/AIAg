# %% [markdown]
# <a href="https://colab.research.google.com/github/gulabpatel/AIAg/blob/main/GIS/Geospatial/13_Visualizing_Raster_Data_with_Leafmap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![image](https://studiolab.sagemaker.aws/studiolab.svg)](https://studiolab.sagemaker.aws/import/github/opengeos/geoai/blob/main/docs/examples/dataviz/raster_viz.ipynb)
# [![image](https://img.shields.io/badge/Open-Planetary%20Computer-black?style=flat&logo=microsoft)](https://pccompute.westeurope.cloudapp.azure.com/compute/hub/user-redirect/git-pull?repo=https://github.com/opengeos/geoai&urlpath=lab/tree/geoai/docs/examples/dataviz/raster_viz.ipynb&branch=main)
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://githubtocolab.com/opengeos/geoai/blob/main/docs/examples/dataviz/raster_viz.ipynb)
#
# # Visualizing Raster Data with Leafmap
#
# This notebook demonstrates how to visualize raster data using [leafmap](https://leafmap.org/). Leafmap can visualize raster data (e.g., Cloud Optimized GeoTIFF) stored in a local file or on the cloud (e.g., AWS S3). It can also visualize raster data stored in a [STAC](https://stacspec.org/) catalog.
#
# ## Installation
#
# Uncomment the following line to install the required packages if needed.

# %%
# %pip install localtileserver
# Out:
# Requirement already satisfied: localtileserver in /usr/local/lib/python3.10/dist-packages (0.7.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from localtileserver) (8.1.7)
# Requirement already satisfied: flask<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from localtileserver) (2.2.5)
# Requirement already satisfied: Flask-Caching in /usr/local/lib/python3.10/dist-packages (from localtileserver) (2.1.0)
# Requirement already satisfied: flask-cors in /usr/local/lib/python3.10/dist-packages (from localtileserver) (4.0.0)
# Requirement already satisfied: flask-restx>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from localtileserver) (1.2.0)
# Requirement already satisfied: large-image[rasterio]>=1.22.2 in /usr/local/lib/python3.10/dist-packages (from localtileserver) (1.26.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from localtileserver) (2.31.0)
# Requirement already satisfied: server-thread in /usr/local/lib/python3.10/dist-packages (from localtileserver) (0.2.0)
# Requirement already satisfied: scooby in /usr/local/lib/python3.10/dist-packages (from localtileserver) (0.9.2)
# Requirement already satisfied: werkzeug in /usr/local/lib/python3.10/dist-packages (from localtileserver) (2.3.8)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from flask<3,>=2.0.0->localtileserver) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from flask<3,>=2.0.0->localtileserver) (2.1.2)
# Requirement already satisfied: aniso8601>=0.82 in /usr/local/lib/python3.10/dist-packages (from flask-restx>=0.5.0->localtileserver) (9.0.1)
# Requirement already satisfied: jsonschema<=4.17.3 in /usr/local/lib/python3.10/dist-packages (from flask-restx>=0.5.0->localtileserver) (4.17.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from flask-restx>=0.5.0->localtileserver) (2023.3.post1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from flask-restx>=0.5.0->localtileserver) (6.1.1)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from large-image[rasterio]>=1.22.2->localtileserver) (5.3.2)
# Requirement already satisfied: palettable in /usr/local/lib/python3.10/dist-packages (from large-image[rasterio]>=1.22.2->localtileserver) (3.3.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from large-image[rasterio]>=1.22.2->localtileserver) (9.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from large-image[rasterio]>=1.22.2->localtileserver) (1.23.5)
# Requirement already satisfied: large-image-source-rasterio>=1.26.1 in /usr/local/lib/python3.10/dist-packages (from large-image[rasterio]>=1.22.2->localtileserver) (1.26.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug->localtileserver) (2.1.3)
# Requirement already satisfied: cachelib<0.10.0,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from Flask-Caching->localtileserver) (0.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->localtileserver) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->localtileserver) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->localtileserver) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->localtileserver) (2023.7.22)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.10/dist-packages (from server-thread->localtileserver) (0.24.0.post1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema<=4.17.3->flask-restx>=0.5.0->localtileserver) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema<=4.17.3->flask-restx>=0.5.0->localtileserver) (0.20.0)
# Requirement already satisfied: rasterio>=1.3 in /usr/local/lib/python3.10/dist-packages (from large-image-source-rasterio>=1.26.1->large-image[rasterio]>=1.22.2->localtileserver) (1.3.9)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from large-image-source-rasterio>=1.26.1->large-image[rasterio]>=1.22.2->localtileserver) (23.2)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn->server-thread->localtileserver) (0.14.0)
# Requirement already satisfied: typing-extensions>=4.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn->server-thread->localtileserver) (4.8.0)
# Requirement already satisfied: affine in /usr/local/lib/python3.10/dist-packages (from rasterio>=1.3->large-image-source-rasterio>=1.26.1->large-image[rasterio]>=1.22.2->localtileserver) (2.4.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio>=1.3->large-image-source-rasterio>=1.26.1->large-image[rasterio]>=1.22.2->localtileserver) (0.7.2)
# Requirement already satisfied: snuggs>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from rasterio>=1.3->large-image-source-rasterio>=1.26.1->large-image[rasterio]>=1.22.2->localtileserver) (1.4.7)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio>=1.3->large-image-source-rasterio>=1.26.1->large-image[rasterio]>=1.22.2->localtileserver) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from rasterio>=1.3->large-image-source-rasterio>=1.26.1->large-image[rasterio]>=1.22.2->localtileserver) (67.7.2)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.10/dist-packages (from snuggs>=1.4.1->rasterio>=1.3->large-image-source-rasterio>=1.26.1->large-image[rasterio]>=1.22.2->localtileserver) (3.1.1)

# %%
# %pip install "leafmap[raster]"
# Out:
# Requirement already satisfied: leafmap[raster] in /usr/local/lib/python3.10/dist-packages (0.29.2)
# Requirement already satisfied: bqplot in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (0.12.42)
# Requirement already satisfied: colour in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (0.1.5)
# Requirement already satisfied: duckdb in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (0.9.2)
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (0.14.0)
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (4.6.6)
# Requirement already satisfied: geojson in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (3.1.0)
# Requirement already satisfied: ipyevents in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (2.0.2)
# Requirement already satisfied: ipyfilechooser in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (0.6.0)
# Requirement already satisfied: ipyleaflet in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (0.17.4)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (7.7.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (1.5.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (5.15.0)
# Requirement already satisfied: pyshp in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (2.3.1)
# Requirement already satisfied: pystac-client in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (0.7.5)
# Requirement already satisfied: python-box in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (7.1.1)
# Requirement already satisfied: scooby in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (0.9.2)
# Requirement already satisfied: whiteboxgui in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (2.3.0)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (2023.10.1)
# Requirement already satisfied: localtileserver in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (0.7.2)
# Requirement already satisfied: jupyter-server-proxy in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (4.1.0)
# Requirement already satisfied: rio-cogeo in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (5.0.0)
# Requirement already satisfied: rioxarray in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (0.15.0)
# Requirement already satisfied: netcdf4 in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (1.6.5)
# Requirement already satisfied: pynhd in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (0.15.2)
# Requirement already satisfied: py3dep in /usr/local/lib/python3.10/dist-packages (from leafmap[raster]) (0.15.2)
# Requirement already satisfied: traitlets>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from bqplot->leafmap[raster]) (5.7.1)
# Requirement already satisfied: traittypes>=0.0.6 in /usr/local/lib/python3.10/dist-packages (from bqplot->leafmap[raster]) (0.2.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->leafmap[raster]) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->leafmap[raster]) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->leafmap[raster]) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->leafmap[raster]) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->leafmap[raster]) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->leafmap[raster]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->leafmap[raster]) (2023.3.post1)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium->leafmap[raster]) (0.7.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium->leafmap[raster]) (3.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium->leafmap[raster]) (2.31.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown->leafmap[raster]) (3.13.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown->leafmap[raster]) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown->leafmap[raster]) (4.66.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown->leafmap[raster]) (4.11.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from jupyter-server-proxy->leafmap[raster]) (3.8.6)
# Requirement already satisfied: jupyter-server>=1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server-proxy->leafmap[raster]) (1.24.0)
# Requirement already satisfied: simpervisor>=1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server-proxy->leafmap[raster]) (1.0.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from localtileserver->leafmap[raster]) (8.1.7)
# Requirement already satisfied: flask<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from localtileserver->leafmap[raster]) (2.2.5)
# Requirement already satisfied: Flask-Caching in /usr/local/lib/python3.10/dist-packages (from localtileserver->leafmap[raster]) (2.1.0)
# Requirement already satisfied: flask-cors in /usr/local/lib/python3.10/dist-packages (from localtileserver->leafmap[raster]) (4.0.0)
# Requirement already satisfied: flask-restx>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from localtileserver->leafmap[raster]) (1.2.0)
# Requirement already satisfied: large-image[rasterio]>=1.22.2 in /usr/local/lib/python3.10/dist-packages (from localtileserver->leafmap[raster]) (1.26.1)
# Requirement already satisfied: server-thread in /usr/local/lib/python3.10/dist-packages (from localtileserver->leafmap[raster]) (0.2.0)
# Requirement already satisfied: werkzeug in /usr/local/lib/python3.10/dist-packages (from localtileserver->leafmap[raster]) (2.3.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->leafmap[raster]) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->leafmap[raster]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->leafmap[raster]) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->leafmap[raster]) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->leafmap[raster]) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->leafmap[raster]) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->leafmap[raster]) (3.1.1)
# Requirement already satisfied: cftime in /usr/local/lib/python3.10/dist-packages (from netcdf4->leafmap[raster]) (1.6.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from netcdf4->leafmap[raster]) (2023.7.22)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->leafmap[raster]) (8.2.3)
# Requirement already satisfied: async-retriever<0.16,>=0.15.2 in /usr/local/lib/python3.10/dist-packages (from py3dep->leafmap[raster]) (0.15.2)
# Requirement already satisfied: cytoolz in /usr/local/lib/python3.10/dist-packages (from py3dep->leafmap[raster]) (0.12.2)
# Requirement already satisfied: geopandas>=0.10 in /usr/local/lib/python3.10/dist-packages (from py3dep->leafmap[raster]) (0.13.2)
# Requirement already satisfied: pygeoogc<0.16,>=0.15.2 in /usr/local/lib/python3.10/dist-packages (from py3dep->leafmap[raster]) (0.15.2)
# Requirement already satisfied: pygeoutils<0.16,>=0.15.2 in /usr/local/lib/python3.10/dist-packages (from py3dep->leafmap[raster]) (0.15.2)
# Requirement already satisfied: rasterio>=1.2 in /usr/local/lib/python3.10/dist-packages (from py3dep->leafmap[raster]) (1.3.9)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from py3dep->leafmap[raster]) (1.11.3)
# Requirement already satisfied: shapely>=1.8.5 in /usr/local/lib/python3.10/dist-packages (from py3dep->leafmap[raster]) (2.0.2)
# Requirement already satisfied: xarray>=2023.01 in /usr/local/lib/python3.10/dist-packages (from py3dep->leafmap[raster]) (2023.7.0)
# Requirement already satisfied: pyproj>=2.2 in /usr/local/lib/python3.10/dist-packages (from rioxarray->leafmap[raster]) (3.6.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from pynhd->leafmap[raster]) (3.2.1)
# Requirement already satisfied: pyarrow>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from pynhd->leafmap[raster]) (9.0.0)
# Requirement already satisfied: pystac[validation]>=1.8.2 in /usr/local/lib/python3.10/dist-packages (from pystac-client->leafmap[raster]) (1.8.3)
# Requirement already satisfied: morecantile<6.0,>=5.0 in /usr/local/lib/python3.10/dist-packages (from rio-cogeo->leafmap[raster]) (5.0.0)
# Requirement already satisfied: pydantic~=2.0 in /usr/local/lib/python3.10/dist-packages (from rio-cogeo->leafmap[raster]) (2.5.2)
# Requirement already satisfied: ipytree in /usr/local/lib/python3.10/dist-packages (from whiteboxgui->leafmap[raster]) (0.2.2)
# Requirement already satisfied: whitebox in /usr/local/lib/python3.10/dist-packages (from whiteboxgui->leafmap[raster]) (2.3.1)
# Requirement already satisfied: aiohttp-client-cache>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from async-retriever<0.16,>=0.15.2->py3dep->leafmap[raster]) (0.10.0)
# Requirement already satisfied: aiosqlite in /usr/local/lib/python3.10/dist-packages (from async-retriever<0.16,>=0.15.2->py3dep->leafmap[raster]) (0.19.0)
# Requirement already satisfied: ujson in /usr/local/lib/python3.10/dist-packages (from async-retriever<0.16,>=0.15.2->py3dep->leafmap[raster]) (5.8.0)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from flask<3,>=2.0.0->localtileserver->leafmap[raster]) (2.1.2)
# Requirement already satisfied: aniso8601>=0.82 in /usr/local/lib/python3.10/dist-packages (from flask-restx>=0.5.0->localtileserver->leafmap[raster]) (9.0.1)
# Requirement already satisfied: jsonschema<=4.17.3 in /usr/local/lib/python3.10/dist-packages (from flask-restx>=0.5.0->localtileserver->leafmap[raster]) (4.17.3)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from flask-restx>=0.5.0->localtileserver->leafmap[raster]) (6.1.1)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas>=0.10->py3dep->leafmap[raster]) (1.9.5)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap[raster]) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap[raster]) (6.3.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap[raster]) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap[raster]) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap[raster]) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap[raster]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap[raster]) (3.0.41)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap[raster]) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap[raster]) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap[raster]) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap[raster]) (4.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium->leafmap[raster]) (2.1.3)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.0->jupyter-server-proxy->leafmap[raster]) (3.7.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.0->jupyter-server-proxy->leafmap[raster]) (23.1.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.0->jupyter-server-proxy->leafmap[raster]) (5.5.0)
# Requirement already satisfied: nbconvert>=6.4.4 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.0->jupyter-server-proxy->leafmap[raster]) (6.5.4)
# Requirement already satisfied: nbformat>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.0->jupyter-server-proxy->leafmap[raster]) (5.9.2)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.0->jupyter-server-proxy->leafmap[raster]) (0.18.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.0->jupyter-server-proxy->leafmap[raster]) (23.2.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.0->jupyter-server-proxy->leafmap[raster]) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.0->jupyter-server-proxy->leafmap[raster]) (0.18.0)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.0->jupyter-server-proxy->leafmap[raster]) (1.6.4)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from large-image[rasterio]>=1.22.2->localtileserver->leafmap[raster]) (5.3.2)
# Requirement already satisfied: palettable in /usr/local/lib/python3.10/dist-packages (from large-image[rasterio]>=1.22.2->localtileserver->leafmap[raster]) (3.3.3)
# Requirement already satisfied: large-image-source-rasterio>=1.26.1 in /usr/local/lib/python3.10/dist-packages (from large-image[rasterio]>=1.22.2->localtileserver->leafmap[raster]) (1.26.1)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from morecantile<6.0,>=5.0->rio-cogeo->leafmap[raster]) (23.1.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic~=2.0->rio-cogeo->leafmap[raster]) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /usr/local/lib/python3.10/dist-packages (from pydantic~=2.0->rio-cogeo->leafmap[raster]) (2.14.5)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic~=2.0->rio-cogeo->leafmap[raster]) (4.8.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from pygeoogc<0.16,>=0.15.2->py3dep->leafmap[raster]) (0.7.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from pygeoogc<0.16,>=0.15.2->py3dep->leafmap[raster]) (1.3.2)
# Requirement already satisfied: multidict in /usr/local/lib/python3.10/dist-packages (from pygeoogc<0.16,>=0.15.2->py3dep->leafmap[raster]) (6.0.4)
# Requirement already satisfied: owslib>=0.27.2 in /usr/local/lib/python3.10/dist-packages (from pygeoogc<0.16,>=0.15.2->py3dep->leafmap[raster]) (0.29.3)
# Requirement already satisfied: requests-cache>=0.9.6 in /usr/local/lib/python3.10/dist-packages (from pygeoogc<0.16,>=0.15.2->py3dep->leafmap[raster]) (1.1.1)
# Requirement already satisfied: url-normalize>=1.4 in /usr/local/lib/python3.10/dist-packages (from pygeoogc<0.16,>=0.15.2->py3dep->leafmap[raster]) (1.4.3)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from pygeoogc<0.16,>=0.15.2->py3dep->leafmap[raster]) (2.0.7)
# Requirement already satisfied: yarl in /usr/local/lib/python3.10/dist-packages (from pygeoogc<0.16,>=0.15.2->py3dep->leafmap[raster]) (1.9.2)
# Requirement already satisfied: affine in /usr/local/lib/python3.10/dist-packages (from rasterio>=1.2->py3dep->leafmap[raster]) (2.4.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio>=1.2->py3dep->leafmap[raster]) (0.7.2)
# Requirement already satisfied: snuggs>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from rasterio>=1.2->py3dep->leafmap[raster]) (1.4.7)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio>=1.2->py3dep->leafmap[raster]) (1.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium->leafmap[raster]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium->leafmap[raster]) (3.4)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->leafmap[raster]) (6.5.5)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jupyter-server-proxy->leafmap[raster]) (4.0.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jupyter-server-proxy->leafmap[raster]) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jupyter-server-proxy->leafmap[raster]) (1.3.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown->leafmap[raster]) (2.5)
# Requirement already satisfied: toolz>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from cytoolz->py3dep->leafmap[raster]) (0.12.0)
# Requirement already satisfied: cachelib<0.10.0,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from Flask-Caching->localtileserver->leafmap[raster]) (0.9.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests->folium->leafmap[raster]) (1.7.1)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.10/dist-packages (from server-thread->localtileserver->leafmap[raster]) (0.24.0.post1)
# Requirement already satisfied: aiodns in /usr/local/lib/python3.10/dist-packages (from aiohttp->jupyter-server-proxy->leafmap[raster]) (3.1.1)
# Requirement already satisfied: Brotli in /usr/local/lib/python3.10/dist-packages (from aiohttp->jupyter-server-proxy->leafmap[raster]) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.0->jupyter-server-proxy->leafmap[raster]) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.0->jupyter-server-proxy->leafmap[raster]) (1.1.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->leafmap[raster]) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema<=4.17.3->flask-restx>=0.5.0->localtileserver->leafmap[raster]) (0.20.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server>=1.0->jupyter-server-proxy->leafmap[raster]) (4.0.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy->leafmap[raster]) (4.9.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy->leafmap[raster]) (6.1.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy->leafmap[raster]) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy->leafmap[raster]) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy->leafmap[raster]) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy->leafmap[raster]) (0.9.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy->leafmap[raster]) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy->leafmap[raster]) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.2.0->jupyter-server>=1.0->jupyter-server-proxy->leafmap[raster]) (2.19.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap[raster]) (1.5.8)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap[raster]) (1.0.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from owslib>=0.27.2->pygeoogc<0.16,>=0.15.2->py3dep->leafmap[raster]) (6.0.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->leafmap[raster]) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->leafmap[raster]) (0.2.10)
# Requirement already satisfied: cattrs>=22.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache>=0.9.6->pygeoogc<0.16,>=0.15.2->py3dep->leafmap[raster]) (23.2.2)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->jupyter-server>=1.0->jupyter-server-proxy->leafmap[raster]) (21.2.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn->server-thread->localtileserver->leafmap[raster]) (0.14.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap[raster]) (0.2.3)
# Requirement already satisfied: pycares>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from aiodns->aiohttp->jupyter-server-proxy->leafmap[raster]) (4.4.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server>=1.0->jupyter-server-proxy->leafmap[raster]) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy->leafmap[raster]) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server>=1.0->jupyter-server-proxy->leafmap[raster]) (2.21)

# %% [markdown]
# ## COG
#
# A Cloud Optimized GeoTIFF (COG) is a regular GeoTIFF file, aimed at being hosted on a HTTP file server, with an internal organization that enables more efficient workflows on the cloud. It does this by leveraging the ability of clients issuing HTTP GET range requests to ask for just the parts of a file they need. More information about COG can be found at <https://www.cogeo.org/in-depth.html>
#
# For this demo, we will use data from https://www.maxar.com/open-data/california-colorado-fires for mapping California and Colorado fires. Let's create an interactive map and add the COG to the map.

# %%
import leafmap
m = leafmap.Map()
url = 'https://opendata.digitalglobe.com/events/california-fire-2020/pre-event/2018-02-16/pine-gulch-fire20/1030010076004E00.tif'
m.add_cog_layer(url, name="Fire (pre-event)")
m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %% [markdown]
# You can add multiple COGs to the map. Let's add another COG to the map.

# %%
url2 = 'https://opendata.digitalglobe.com/events/california-fire-2020/post-event/2020-08-14/pine-gulch-fire20/10300100AAC8DD00.tif'
m.add_cog_layer(url2, name="Fire (post-event)")
m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %% [markdown]
# ![](https://i.imgur.com/J9fLbYh.png)

# %% [markdown]
# Create a split map for comparing two COGs.

# %%
m = leafmap.Map()
m.split_map(left_layer=url, right_layer=url2)
m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %% [markdown]
# ![](https://i.imgur.com/FJa0Yta.png)

# %% [markdown]
# ## Local Raster
#
# Leafmap can also visualize local GeoTIFF files. Let's download some sample data

# %%
dem_url = 'https://open.gishub.org/data/raster/srtm90.tif'
leafmap.download_file(dem_url, unzip=False)
# Out:
# srtm90.tif already exists. Skip downloading. Set overwrite=True to overwrite.
# '/content/srtm90.tif'

# %% [markdown]
# Visualize a single-band raster.

# %%
m = leafmap.Map()
m.add_raster('srtm90.tif', cmap='terrain', layer_name='DEM')
m
# Out:
# INFO:large_image:Cannot use memcached for caching.
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %% [markdown]
# ![](https://i.imgur.com/7g9huvY.png)

# %%
landsat_url = 'https://open.gishub.org/data/raster/cog.tif'
leafmap.download_file(landsat_url)
# Out:
# Downloading...
# From: https://open.gishub.org/data/raster/cog.tif
# To: /content/cog.tif
# 100%|██████████| 611k/611k [00:00<00:00, 11.4MB/s]
# '/content/cog.tif'

# %% [markdown]
# Visualize a multi-band raster.

# %%
m = leafmap.Map()
m.add_raster('cog.tif', bands=[4, 3, 2], layer_name='Landsat')
m
# Out:
# WARNING:rasterio._env:CPLE_AppDefined in /content/cog.tif: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# WARNING:rasterio._env:CPLE_AppDefined in /content/cog.tif: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# WARNING:rasterio._env:CPLE_AppDefined in /content/cog.tif: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# WARNING:rasterio._env:CPLE_AppDefined in /content/cog.tif: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %% [markdown]
# ![](https://i.imgur.com/euhkajs.png)

# %% [markdown]
# ## STAC
#
# The SpatioTemporal Asset Catalog (STAC) specification provides a common language to describe a range of geospatial information so that it can more easily be indexed and discovered. A SpatioTemporal Asset is any file that represents information about the earth captured in a certain space and time. STAC aims to enable that next generation of geospatial search engines, while also supporting web best practices so geospatial information is more easily surfaced in traditional search engines. More information about STAC can be found at the [STAC website](https://stacspec.org). In this example, we will use a STAC item from the [SPOT Orthoimages of Canada](https://stacindex.org/catalogs/spot-orthoimages-canada-2005) available through the link below:

# %% [markdown]
# Create an interactive map.

# %%
url = 'https://canada-spot-ortho.s3.amazonaws.com/canada_spot_orthoimages/canada_spot5_orthoimages/S5_2007/S5_11055_6057_20070622/S5_11055_6057_20070622.json'
leafmap.stac_bands(url)
# Out:
# ['pan', 'B1', 'B2', 'B3', 'B4']

# %% [markdown]
# Add STAC layers to the map.

# %%
m = leafmap.Map()
m.add_stac_layer(url, bands=['pan'], name='Panchromatic')
m.add_stac_layer(url, bands=['B3', 'B2', 'B1'], name='False color')
m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %% [markdown]
# ![](https://i.imgur.com/IlqsJXK.png)

# %% [markdown]
# ## Custom STAC Catalog

# %% [markdown]
# Provide custom STAC API endpoints as a dictionary in the format of `{"name": "url"}`. The name will show up in the dropdown menu, while the url is the STAC API endpoint that will be used to search for items.

# %%
catalogs = {
    "Element84 Earth Search": "https://earth-search.aws.element84.com/v1",
    "Microsoft Planetary Computer": "https://planetarycomputer.microsoft.com/api/stac/v1",
}

# %%
m = leafmap.Map(center=[40, -100], zoom=4)
m.set_catalog_source(catalogs)
m.add_stac_gui()
m
# Out:
# Map(center=[40, -100], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %% [markdown]
# Once the catalog panel is open, you can search for items from the custom STAC API endpoints. Simply draw a bounding box on the map or zoom to a location of interest. Click on the **Collections** button to retrieve the collections from the custom STAC API endpoints. Next, select a collection from the dropdown menu. Then, click on the **Items** button to retrieve the items from the selected collection. Finally, click on the **Display** button to add the selected item to the map.

# %% [markdown]
# ![](https://i.imgur.com/M8IbRsM.png)

# %%
m.stac_gdf  # The GeoDataFrame of the STAC search results

# %%
m.stac_dict()  # The STAC search results as a dictionary

# %%
m.stac_item  # The selected STAC item of the search result

# %% [markdown]
# ## AWS S3

# %% [markdown]
# To Be able to run this notebook you'll need to have AWS credential available as environment variables. Uncomment the following lines to set the environment variables.

# %%
# os.environ["AWS_ACCESS_KEY_ID"] = "YOUR AWS ACCESS ID HERE"
# os.environ["AWS_SECRET_ACCESS_KEY"] = "YOUR AWS ACCESS KEY HERE"

# %% [markdown]
# In this example, we will use datasets from the [Maxar Open Data Program on AWS](https://registry.opendata.aws/maxar-open-data/).

# %%
BUCKET = "maxar-opendata"
FOLDER = "events/Kahramanmaras-turkey-earthquake-23/"

# %% [markdown]
# List all the datasets in the bucket. Specify a file extension to filter the results if needed.

# %%
items = leafmap.s3_list_objects(BUCKET, FOLDER, ext=".tif")
items[:10]

# %% [markdown]
# Visualize raster datasets from the bucket.

# %%
m = leafmap.Map()
m.add_cog_layer(items[2], name="Maxar")
m

# %% [markdown]
# ![](https://i.imgur.com/NkTZ6Lj.png)
