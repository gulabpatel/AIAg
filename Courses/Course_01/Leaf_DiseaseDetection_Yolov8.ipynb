# %% [markdown]
# <a href="https://colab.research.google.com/github/gulabpatel/AIAg/blob/main/Courses/Course_01/Leaf_DiseaseDetection_Yolov8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="0BeJgd54lC1r8k6c05Qr")
project = rf.workspace("joseph-nelson").project("plantdoc")
dataset = project.version(4).download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics==8.0.134`, to intall it `pip install ultralytics==8.0.134`.
# ...
# Extracting Dataset Version Zip to PlantDoc-4 in yolov8:: 100%|██████████| 5150/5150 [00:02<00:00, 2317.46it/s]

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')

results = model.train(data='/content/PlantDoc-4/data.yaml', epochs=16, batch=16)
# Out:
# Ultralytics YOLOv8.0.199 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model = YOLO('/content/runs/detect/train2/weights/best.pt')

results = model.predict(source='/content/PlantDoc-4/test/images', save=True, stream=True)

for result in results:
  pass
# Out:
# image 1/246 /content/PlantDoc-4/test/images/-2320-Bacterial-Spot-and-Speck_jpg.rf.9d63c6e88cb474baa4d4eab1681f6d41.jpg: 480x640 1 Tomato Septoria leaf spot, 97.3ms
# image 2/246 /content/PlantDoc-4/test/images/0000_jpg.rf.d9be28abba2b4e67431ed005bdde14de.jpg: 640x640 1 grape leaf black rot, 8.2ms
# image 3/246 /content/PlantDoc-4/test/images/000_jpg.rf.e32ba3f04d1e855e58b1b3f5475cf1e5.jpg: 480x640 (no detections), 6.9ms
# image 4/246 /content/PlantDoc-4/test/images/00_jpg.rf.567521ea9c2d0153cb8b96c5bd18e692.jpg: 480x640 1 Bell_pepper leaf, 2 Potato leaf late blights, 7.1ms
# image 5/246 /content/PlantDoc-4/test/images/00pe_jpg.rf.a17680fc7cdfa4c78c70f3ef1a81fd79.jpg: 640x480 1 Apple leaf, 12.6ms
# image 6/246 /content/PlantDoc-4/test/images/01_jpg.rf.132567152237e39d0c9a6f61dfc88873.jpg: 512x640 1 Bell_pepper leaf, 58.8ms
# image 7/246 /content/PlantDoc-4/test/images/02_-Rust-2017-207u24s_jpg.rf.f1a95c4ac228e45d9b83a977e967d31e.jpg: 384x640 (no detections), 54.4ms
# ...
