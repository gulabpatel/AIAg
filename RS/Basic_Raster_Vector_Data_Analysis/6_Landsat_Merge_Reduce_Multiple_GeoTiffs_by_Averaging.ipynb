# %% [markdown]
# <a href="https://colab.research.google.com/github/kevinworthington/geospatial_colab/blob/main/Landsat_Merge_Reduce_Multiple_GeoTiffs_by_Averaging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The following notebook searches for remote sensing data over a period of time and merges these images together by averaging the values of each of the pixels.
#
# The preset boundary box is editable allowing you to choose where you'd like to do your analysis.
#
# Referenced From: https://carpentries-incubator.github.io/geospatial-python/05-access-data.html

# %% [markdown]
# We'll start by installing the needed libraries, but if you have these already, skip to loading the libraries.

# %%
# %%capture
# !pip install leafmap

# %%
# %%capture
# !pip install widgetsnbextension

# %%
# Now load the required libraries, each includes their intended purpose in this project
from pystac_client import Client # To query STAC API endpoint
import planetary_computer # Microsoft Data Catalog library
from shapely.geometry import shape,GeometryCollection,box # To work with drawn geometry
from shapely.geometry.polygon import Polygon
import leafmap # A feature-rich interactive map allow us to save drawn geometry (among other things)
import geojson # To parse geospatial data
import folium # Another interactive map
from shapely.ops import transform # The shapely transform module
import pyproj # A reprojection library
import rioxarray # To open raster images
from rioxarray import merge # To merge raster images
import numpy as np # To math raster images

# %%
# Create a polygon to define our Area of Interest (AOI), this can be updated within our interactive map
drawn_box: dict = {
  "type": "FeatureCollection",
  "features": [
    {
      "type": "Feature",
      "properties": {},
      "geometry": {
        "type": "Polygon",
        "coordinates": [
          [
            [
              -106.05059,
              39.856251
            ],
            [
              -106.05059,
              40.443559
            ],
            [
              -105.182217,
              40.443559
            ],
            [
              -105.182217,
              39.856251
            ],
            [
              -106.05059,
              39.856251
            ]
          ]
        ]
      }
    }
  ]
}

# %%
# Create an interactive map allowing us to edit our initial AOI
# You can delete the existing polygon and/or draw mulitple polygons which will later be combined to create a boundary box used to search for data
m = leafmap.Map(center=[40, -100], zoom=4)
m.edit_vector(drawn_box)
m
# Out:
# Map(center=[40, -100], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %%
# save the drawn polygons
m.save_draw_features("data.geojson")

# %%
# open the saved polygons. This is the only way to avoid copying and pasting the updated geojson
with open('data.geojson', 'r') as file:
    geojson_data = geojson.load(file)

# %%
# Create a boundary box for all the drawn polygons

# Ref: rom https://gis.stackexchange.com/questions/270297/getting-bounding-boxes-for-all-polygons-in-geojson-feature-collection

# Define a list to store the geometry
polygons=[]
for f in geojson_data["features"]:
    polygon: Polygon = shape(f["geometry"])
    polygons.append(polygon)

# Create a colletion with all the geometries
polygons_gc=GeometryCollection(polygons)

# Store the bounds in a new variable
polygons_bbox= box(*polygons_gc.bounds)

# %%
# Create a new interactive map with a boundary around all the shapes drawn earlier

# Create the map
folium_map = folium.Map([polygons_bbox.centroid.y,polygons_bbox.centroid.x], zoom_start=10)

# Add drawn boundaries
folium.GeoJson(geojson_data).add_to(folium_map)

# # Add max bounds
folium.GeoJson(polygons_bbox,
    style_function=lambda feature: {
        "fillColor": "#ff0000",
        "color": "black",
        "weight": 2,
        "dashArray": "5, 5",
    }).add_to(folium_map)

folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_27bdf9a2a468f9438e43fc72691bcc9f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_27bdf9a2a468f9438e43fc72691bcc9f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_27bdf9a2a468f9438e43fc72691bcc9f = L.map(
#                 &quot;map_27bdf9a2a468f9438e43fc72691bcc9f&quot;,
#                 {
#                     center: [40.2295795, -105.5352155],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5bdf9062b4b87e9921c18e413b574ac4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5bdf9062b4b87e9921c18e413b574ac4.addTo(map_27bdf9a2a468f9438e43fc72691bcc9f);
#
#
#
#         function geo_json_5319097a657a7b7edd0f03df736b4cf7_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_5319097a657a7b7edd0f03df736b4cf7 = L.geoJson(null, {
#                 onEachFeature: geo_json_5319097a657a7b7edd0f03df736b4cf7_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_5319097a657a7b7edd0f03df736b4cf7_add (data) {
#             geo_json_5319097a657a7b7edd0f03df736b4cf7
#                 .addData(data);
#         }
#             geo_json_5319097a657a7b7edd0f03df736b4cf7_add({&quot;crs&quot;: {&quot;properties&quot;: {&quot;name&quot;: &quot;urn:ogc:def:crs:OGC:1.3:CRS84&quot;}, &quot;type&quot;: &quot;name&quot;}, &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-106.05059, 39.856251], [-106.05059, 40.443559], [-105.182217, 40.443559], [-105.182217, 39.856251], [-106.05059, 39.856251]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-105.135242, 40.550755], [-105.135242, 40.602908], [-105.019841, 40.602908], [-105.019841, 40.550755], [-105.135242, 40.550755]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;name&quot;: &quot;data&quot;, &quot;type&quot;: &quot;FeatureCollection&quot;});
#         geo_json_5319097a657a7b7edd0f03df736b4cf7.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_5319097a657a7b7edd0f03df736b4cf7.addTo(map_27bdf9a2a468f9438e43fc72691bcc9f);
#
#
#         function geo_json_2ad9bc3872166750c2c8c584bdd1c4b3_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#ff0000&quot;, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_2ad9bc3872166750c2c8c584bdd1c4b3_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_2ad9bc3872166750c2c8c584bdd1c4b3 = L.geoJson(null, {
#                 onEachFeature: geo_json_2ad9bc3872166750c2c8c584bdd1c4b3_onEachFeature,
#
#                 style: geo_json_2ad9bc3872166750c2c8c584bdd1c4b3_styler,
#             ...{
# }
#         });
#
#         function geo_json_2ad9bc3872166750c2c8c584bdd1c4b3_add (data) {
#             geo_json_2ad9bc3872166750c2c8c584bdd1c4b3
#                 .addData(data);
#         }
#             geo_json_2ad9bc3872166750c2c8c584bdd1c4b3_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-105.019841, 39.856251], [-105.019841, 40.602908], [-106.05059, 40.602908], [-106.05059, 39.856251], [-105.019841, 39.856251]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_2ad9bc3872166750c2c8c584bdd1c4b3.addTo(map_27bdf9a2a468f9438e43fc72691bcc9f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Connect to the STAC endpoint used to find satellite data
cmr_api_url =  "https://planetarycomputer.microsoft.com/api/stac/v1"
client = Client.open(cmr_api_url, modifier=planetary_computer.sign_inplace,)

# Run search
search = client.search(
    collections=["landsat-c2-l2"],
    bbox=polygons_bbox.bounds,
    datetime="2021-03-01/2021-03-30",
)
# Retrieve search results
items = search.item_collection()
print(len(items))
# Out:
# 9

# %%
# Inspect the first item
items[0]
# Out:
# <Item id=LC08_L2SP_033033_20210324_02_T1>

# %%
# visualize the first item
m = leafmap.Map(center=[polygons_bbox.centroid.y,polygons_bbox.centroid.x])
m.add_cog_layer(items[0].assets["nir08"].href, name="")


m
# Out:
# Map(center=[40.2295795, -105.5352155], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_tit…

# %%
# Sort the items by cloud_cover
items = search.item_collection()

items_sorted = sorted(items, key=lambda x: x.properties["eo:cloud_cover"])

# %%
# Lets short list the items which we'll merge later and then clip
# Start by gathering the hrefs
item_hrefs=[]

for i in items_sorted[0:4]:
    item_hrefs.append(i.assets["nir08"].href)

# %%
items[0].properties
# Out:
# {'gsd': 30,
#  'created': '2022-05-06T18:07:26.417023Z',
#  'sci:doi': '10.5066/P9OGBGM6',
#  'datetime': '2021-03-24T17:37:30.160377Z',
#  'platform': 'landsat-8',
#  'proj:shape': [7841, 7711],
#  'description': 'Landsat Collection 2 Level-2',
#  'instruments': ['oli', 'tirs'],
#  'eo:cloud_cover': 83.11,
#  'proj:transform': [30.0, 0.0, 411585.0, 0.0, -30.0, 4423215.0],
#  'view:off_nadir': 0,
#  'landsat:wrs_row': '033',
#  'landsat:scene_id': 'LC80330332021083LGN00',
#  'landsat:wrs_path': '033',
#  'landsat:wrs_type': '2',
#  'view:sun_azimuth': 146.38573471,
#  'landsat:correction': 'L2SP',
#  'view:sun_elevation': 47.79202879,
#  'landsat:cloud_cover_land': 83.11,
#  'landsat:collection_number': '02',
#  'landsat:collection_category': 'T1',
#  'proj:code': 'EPSG:32613'}

# %%
# View the map file 'boundary'
# Use the file's lat and long column to center the map

folium_map = folium.Map([polygons_bbox.centroid.y,polygons_bbox.centroid.x], zoom_start = 10)

# Add the boundary
folium.GeoJson(polygons_bbox).add_to(folium_map)

for id, i in enumerate(item_hrefs):
      raster = rioxarray.open_rasterio(item_hrefs[id])
      # Create boundary boxes
      # use teh first item to create a reprojection transformer
      project = pyproj.Transformer.from_crs(items[0].properties["proj:code"], 4326, always_xy=True).transform

      bbox = box(*raster.rio.bounds())
      bbox_transformed = transform(project, bbox)

      folium.GeoJson(bbox_transformed,
          style_function=lambda feature: {
          "color": "purple",
      }).add_to(folium_map)

folium.LayerControl().add_to(folium_map)
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7d18ee8b60afe5fa7a843cdb9d306917 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7d18ee8b60afe5fa7a843cdb9d306917&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7d18ee8b60afe5fa7a843cdb9d306917 = L.map(
#                 &quot;map_7d18ee8b60afe5fa7a843cdb9d306917&quot;,
#                 {
#                     center: [40.2295795, -105.5352155],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8e591c71f36ab90c91ccfa42aaeb9307 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8e591c71f36ab90c91ccfa42aaeb9307.addTo(map_7d18ee8b60afe5fa7a843cdb9d306917);
#
#
#
#         function geo_json_2c8be89139dd374e9657c163c580768f_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_2c8be89139dd374e9657c163c580768f = L.geoJson(null, {
#                 onEachFeature: geo_json_2c8be89139dd374e9657c163c580768f_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_2c8be89139dd374e9657c163c580768f_add (data) {
#             geo_json_2c8be89139dd374e9657c163c580768f
#                 .addData(data);
#         }
#             geo_json_2c8be89139dd374e9657c163c580768f_add({&quot;coordinates&quot;: [[[-105.019841, 39.856251], [-105.019841, 40.602908], [-106.05059, 40.602908], [-106.05059, 39.856251], [-105.019841, 39.856251]]], &quot;type&quot;: &quot;Polygon&quot;});
#         geo_json_2c8be89139dd374e9657c163c580768f.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_2c8be89139dd374e9657c163c580768f.addTo(map_7d18ee8b60afe5fa7a843cdb9d306917);
#
#
#         function geo_json_0ee5355d32261dc62e796e42e0ee31fd_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;purple&quot;};
#             }
#         }
#
#         function geo_json_0ee5355d32261dc62e796e42e0ee31fd_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_0ee5355d32261dc62e796e42e0ee31fd = L.geoJson(null, {
#                 onEachFeature: geo_json_0ee5355d32261dc62e796e42e0ee31fd_onEachFeature,
#
#                 style: geo_json_0ee5355d32261dc62e796e42e0ee31fd_styler,
#             ...{
# }
#         });
#
#         function geo_json_0ee5355d32261dc62e796e42e0ee31fd_add (data) {
#             geo_json_0ee5355d32261dc62e796e42e0ee31fd
#                 .addData(data);
#         }
#             geo_json_0ee5355d32261dc62e796e42e0ee31fd_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-104.497103991589, 39.37655275901054], [-104.48228605146737, 41.34166037906005], [-107.44698802539857, 41.31680596352754], [-107.37702852915027, 39.353356417699324], [-104.497103991589, 39.37655275901054]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_0ee5355d32261dc62e796e42e0ee31fd.addTo(map_7d18ee8b60afe5fa7a843cdb9d306917);
#
#
#         function geo_json_a563ff2b9c296eee6e62dbdf1144f45e_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;purple&quot;};
#             }
#         }
#
#         function geo_json_a563ff2b9c296eee6e62dbdf1144f45e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_a563ff2b9c296eee6e62dbdf1144f45e = L.geoJson(null, {
#                 onEachFeature: geo_json_a563ff2b9c296eee6e62dbdf1144f45e_onEachFeature,
#
#                 style: geo_json_a563ff2b9c296eee6e62dbdf1144f45e_styler,
#             ...{
# }
#         });
#
#         function geo_json_a563ff2b9c296eee6e62dbdf1144f45e_add (data) {
#             geo_json_a563ff2b9c296eee6e62dbdf1144f45e
#                 .addData(data);
#         }
#             geo_json_a563ff2b9c296eee6e62dbdf1144f45e_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-103.44858771795269, 37.94533647848559], [-103.40573829506454, 39.88594794990151], [-106.28324587176284, 39.88980697407575], [-106.24874968994558, 37.94893867395829], [-103.44858771795269, 37.94533647848559]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_a563ff2b9c296eee6e62dbdf1144f45e.addTo(map_7d18ee8b60afe5fa7a843cdb9d306917);
#
#
#         function geo_json_67677c1ca396c85825bebc6896823052_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;pu

# %% [markdown]
# # Merge the datasets

# %%
# Start by creating a list of the images
nir_rasters=[]
for i in item_hrefs:
    nir_rasters.append(rioxarray.open_rasterio(i, masked=True))

# %%
# Set our boundry to the CRS of the raster so we can use it to clip
project_from_4326 = pyproj.Transformer.from_crs(4326,items[0].properties["proj:code"], always_xy=True).transform
polygons_bbox_transformed = transform(project_from_4326, polygons_bbox)

# %%
help (merge.merge_arrays)
# Out:
# Help on function merge_arrays in module rioxarray.merge:
#
# merge_arrays(dataarrays: collections.abc.Sequence[xarray.core.dataarray.DataArray], *, bounds: Optional[tuple] = None, res: Optional[tuple] = None, nodata: Optional[float] = None, precision: Optional[float] = None, method: Union[str, Callable, NoneType] = None, crs: Optional[rasterio.crs.CRS] = None, parse_coordinates: bool = True) -> xarray.core.dataarray.DataArray
#     Merge data arrays geospatially.
#
#     Uses :func:`rasterio.merge.merge`
#
#     .. versionadded:: 0.2 crs
#
#     Parameters
#     ----------
#     dataarrays: list[xarray.DataArray]
#         List of multiple xarray.DataArray with all geo attributes.
#         The first one is assumed to have the same
#         CRS, dtype, and dimensions as the others in the array.
#     bounds: tuple, optional
#         Bounds of the output image (left, bottom, right, top).
#         If not set, bounds are determined from bounds of input DataArrays.
#     res: tuple, optional
#         Output resolution in units of coordinate reference system.
#         If not set, the resolution of the first DataArray is used.
#         If a single value is passed, output pixels will be square.
#     nodata: float, optional
#         nodata value to use in output file.
#         If not set, uses the nodata value in the first input DataArray.
#     precision: float, optional
#         Number of decimal points of precision when computing inverse transform.
#     method: str or callable, optional
#         See :func:`rasterio.merge.merge` for details.
#     crs: rasterio.crs.CRS, optional
#         Output CRS. If not set, the CRS of the first DataArray is used.
#     parse_coordinates: bool, optional
#         If False, it will disable loading spatial coordinates.
#
#     Returns
#     -------
#     :obj:`xarray.DataArray`:
#         The geospatially merged data.

# %%
# create a custom merge function allowing us to average the overlapping pixels and merger
def custom_merge_avg(old_data, new_data, old_nodata, new_nodata, index=None, roff=None, coff=None):
    old_data[:] = np.nanmean( np.array([ old_data, new_data ]), axis=0 )

nir_merged = merge.merge_arrays(nir_rasters,bounds=polygons_bbox_transformed.bounds,method = custom_merge_avg)

# %%
nir_merged
# Out:
# <xarray.DataArray (band: 1, y: 2780, x: 2940)> Size: 33MB
# array([[[18292.5  , 17552.   , 15417.   , ..., 19267.   , 19452.   ,
#           7870.5  ],
#         [18385.   , 18108.   , 17366.5  , ..., 19443.375, 19256.75 ,
#           7870.5  ],
#         [18292.5  , 18385.   , 18200.   , ..., 20186.   , 19660.75 ,
#           7684.   ],
#         ...,
#         [ 8081.25 ,  7760.5  ,  6889.25 , ..., 22580.   , 21468.188,
#           4865.75 ],
#         [ 7714.75 ,  6889.25 ,  5647.   , ..., 22230.562, 21244.   ,
#           4865.75 ],
#         [14971.5  , 13135.   , 10925.   , ..., 23204.375, 23323.625,
#           9731.5  ]]], dtype=float32)
# Coordinates:
#   * x            (x) float64 24kB 4.101e+05 4.102e+05 ... 4.983e+05 4.983e+05
#   * y            (y) float64 22kB 4.495e+06 4.495e+06 ... 4.412e+06 4.412e+06
#     spatial_ref  int64 8B 0
#   * band         (band) int64 8B 1
# Attributes:
#     AREA_OR_POINT:  Area

# %%
nir_merged.rio.crs
# Out:
# CRS.from_epsg(32613)

# %%
# save our merged geotiff
nir_merged.to_netcdf("output_data/nir_merged.nc")

# %%
satellite = leafmap.download_file("output_data/nir_merged.nc","output_data/nir_merged.nc")
m = leafmap.Map()
m.add_raster(satellite)
m
# Out:
# output_data/nir_merged.nc already exists. Skip downloading. Set overwrite=True to overwrite.
# Map(center=[40.229613, -105.54083750000001], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_…
